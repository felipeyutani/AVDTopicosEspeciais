# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeyutani/AVDTopicosEspeciais/blob/main/avdtopicosespeciais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Seguem abaixo lista de itens que devem estar implementados no código:
#
# - Desenvolva um código que lhe permita abrir uma imagem RGB ou BGR de sua preferência, utilizando a interface python do OpenCV.
#
# - Utilizando o código fonte das nossas aulas como base, carregue uma imagem contendo pelo menos duas faces, depois carregue o modelo de detecção de faces utilizado nas nossa aula sobre a dlib.
#
# - Construa um código de detecção de faces, encontre a caixa envolvente da face na imagem. Depois de encontrada cada face, encontre os marcos faciais de cada uma das faces.
#
# - Pinte o retângulo ao redor da(s) face(s) encontrada(s) e cada um dos marcos faciais encontrads. Exiba a imagem pintada na tela. Documente as funções utilizadas no código.

# %%
import dlib

from PIL import Image
import cv2
import numpy
from google.colab.patches import cv2_imshow
from skimage import io

# %% [markdown]
# **Desenvolva um código que lhe permita abrir uma imagem RGB ou BGR de sua preferência, utilizando a interface python do OpenCV.**

# %%
img = cv2.imread('faces.png')

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=626x618 at 0x7F665AC139D0>

# %% [markdown]
# **Utilizando o código fonte das nossas aulas como base, carregue uma imagem contendo pelo menos duas faces, depois carregue o modelo de detecção de faces utilizado nas nossa aula sobre a dlib.**

# %%
face_detector = dlib.get_frontal_face_detector()

img = cv2.imread('faces.png')
deteccoes = face_detector(img, 1)
for face in deteccoes:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(img, (l, t), (r, b), (255, 0, 0), 2)


cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=626x618 at 0x7F665ABDEA10>

# %% [markdown]
# **Construa um código de detecção de faces, encontre a caixa envolvente da face na imagem. Depois de encontrada cada face, encontre os marcos faciais de cada uma das faces.**

# %%
landmark_detector = dlib.shape_predictor('shape_predictor_68_face_landmarks.dat')

img = cv2.imread('faces.png')

detect = detector_face(img, 1)
for face in detect:
  pontos = landmark_detector(img, face)
  for ponto in pontos.parts():
    cv2.circle(img, (ponto.x, ponto.y), 1, (0, 255, 0), 1)

  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(img, (l,t), (r, b), (255, 0, 0), 2)


cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=626x618 at 0x7F665A4AB290>

# %% [markdown]
# **Pinte o retângulo ao redor da(s) face(s) encontrada(s) e cada um dos marcos faciais encontrads. Exiba a imagem pintada na tela. Documente as funções utilizadas no código.**

# %%
img = cv2.imread('faces.png')

detect = detector_face(img, 1)
for face in detect:
  pontos = landmark_detector(img, face)
  for ponto in pontos.parts():
    cv2.circle(img, (ponto.x, ponto.y), 1, (0, 255, 0), 1)

  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(img, (l,t), (r, b), (255, 0, 0), 2)


cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=626x618 at 0x7F665AC87810>
